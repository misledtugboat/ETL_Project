# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests

# %%
import pandas as pd

# %%
url = "https://www.boxofficemojo.com/alltime/world/"

# %%
tables = pd.read_html(url)[1]
tables
# Out:
#         0                                      1       2          3  \
# 0    Rank                                  Title  Studio  Worldwide
# 1       1                      Avengers: Endgame      BV   $2,797.8
# 2       2                                 Avatar     Fox   $2,789.7
# 3       3                                Titanic    Par.   $2,187.5
# 4       4           Star Wars: The Force Awakens      BV   $2,068.2
# ..    ...                                    ...     ...        ...
# 96     96                                   2012    Sony     $769.7
# 97     97  Fast & Furious Presents: Hobbs & Shaw    Uni.     $758.7
# 98     98                             Maleficent      BV     $758.5
# 99     99                      The Da Vinci Code    Sony     $758.2
# 100   100                 The Amazing Spider-Man    Sony     $757.9
#
#                 4             5             6             7      8
# 0    Domestic / %  Domestic / %  Overseas / %  Overseas / %  Year^
# ...

# %%
url2 = "https://www.boxofficemojo.com/alltime/world/?pagenum=2&p=.htm"

# %%
tables2 = pd.read_html(url2)[1]
tables2
# Out:
#         0                                      1       2          3  \
# 0    Rank                                  Title  Studio  Worldwide
# 1     101  The Hunger Games: Mockingjay - Part 1     LGF     $755.4
# 2     102                    Shrek Forever After    P/DW     $752.6
# 3     103             X-Men: Days of Future Past     Fox     $747.9
# 4     104     Madagascar 3: Europe's Most Wanted    P/DW     $746.9
# ..    ...                                    ...     ...        ...
# 96    196                        Godzilla (2014)      WB     $529.1
# 97    197  Hotel Transylvania 3: Summer Vacation    Sony     $528.6
# 98    198                          The Boss Baby     Fox     $528.0
# 99    199                     The Simpsons Movie     Fox     $527.1
# 100   200                                Dunkirk      WB     $526.9
#
#                 4             5             6             7      8
# 0    Domestic / %  Domestic / %  Overseas / %  Overseas / %  Year^
# ...

# %%
url3 = "https://www.boxofficemojo.com/alltime/world/?pagenum=3&p=.htm"
tables3 = pd.read_html(url3)[1]
tables3
# Out:
#         0                                           1       2          3  \
# 0    Rank                                       Title  Studio  Worldwide
# 1     201                             Sherlock Holmes      WB     $524.0
# 2     202                             Kung Fu Panda 3     Fox     $521.2
# 3     203                  Terminator 2: Judgment Day    TriS     $520.9
# 4     204  How to Train Your Dragon: The Hidden World    Uni.     $519.9
# ..    ...                                         ...     ...        ...
# 96    296       The Mummy: Tomb of the Dragon Emperor    Uni.     $401.1
# 97    297                                 Tron Legacy      BV     $400.1
# 98    298                     Mission: Impossible III    Par.     $397.9
# 99    299                 Snow White and the Huntsman    Uni.     $396.6
# 100   300                                      Grease    Par.     $396.2
#
#                 4             5             6             7      8
# ...

# %%
url4 = "https://www.boxofficemojo.com/alltime/world/?pagenum=4&p=.htm"
tables4 = pd.read_html(url4)[1]
tables4
# Out:
#         0                                     1       2          3  \
# 0    Rank                                 Title  Studio  Worldwide
# 1     301           Mamma Mia! Here We Go Again    Uni.     $395.0
# 2     302                              Twilight    Sum.     $393.6
# 3     303               Solo: A Star Wars Story      BV     $392.9
# 4     304               The Wolf of Wall Street    Par.     $392.0
# ..    ...                                   ...     ...        ...
# 96    396                      Star Trek Beyond    Par.     $343.5
# 97    397  Alvin and the Chipmunks: Chipwrecked     Fox     $342.7
# 98    398                       The Flintstones    Uni.     $341.6
# 99    399                                Wanted    Uni.     $341.4
# 100   400                         A Quiet Place    Par.     $340.9
#
#                 4             5             6             7      8
# 0    Domestic / %  Domestic / %  Overseas / %  Overseas / %  Year^
# ...

# %%
url5 = "https://www.boxofficemojo.com/alltime/world/?pagenum=5&p=.htm"
tables5 = pd.read_html(url5)[1]
tables5
# Out:
#         0                                    1       2          3  \
# 0    Rank                                Title  Studio  Worldwide
# 1     401                            Enchanted      BV     $340.5
# 2     402               300: Rise of An Empire      WB     $337.6
# 3     403                       Batman Forever      WB     $336.6
# 4     404  Prince of Persia: The Sands of Time      BV     $336.4
# ..    ...                                  ...     ...        ...
# 96    496                                 Salt    Sony     $293.5
# 97    497                              G-Force      BV     $292.8
# 98    498                         The Departed      WB     $291.5
# 99    499                    What Lies Beneath      DW     $291.4
# 100   500                 Pacific Rim Uprising    Uni.     $290.9
#
#                 4             5             6             7      8
# 0    Domestic / %  Domestic / %  Overseas / %  Overseas / %  Year^
# ...

# %%
url6 = "https://www.boxofficemojo.com/alltime/world/?pagenum=6&p=.htm"
tables6 = pd.read_html(url6)[1]
tables6
# Out:
#         0                                          1       2          3  \
# 0    Rank                                      Title  Studio  Worldwide
# 1     501                        Shakespeare in Love   Mira.     $289.3
# 2     502  Fantastic Four: Rise of the Silver Surfer     Fox     $289.0
# 3     503                                  Divergent    LG/S     $288.9
# 4     504                          Coming to America    Par.     $288.8
# ..    ...                                        ...     ...        ...
# 96    596                                     Eragon     Fox     $249.5
# 97    597                                   The Ring      DW     $249.3
# 98    598                    The Blair Witch Project    Art.     $248.6
# 99    599                                Unbreakable      BV     $248.1
# 100   600                            Dumb and Dumber      NL     $247.3
#
#                 4             5             6             7      8
# ...

# %%
url7 = "https://www.boxofficemojo.com/alltime/world/?pagenum=7&p=.htm"
tables7 = pd.read_html(url7)[1]
tables7
# Out:
#         0                                            1       2          3  \
# 0    Rank                                        Title  Studio  Worldwide
# 1     601                                        Glass    Uni.     $247.0
# 2     602                                  Grown Ups 2    Sony     $247.0
# 3     603                                Love Actually    Uni.     $246.9
# 4     604  Journey to the West: The Demons Strike Back    Sony     $246.6
# ..    ...                                          ...     ...        ...
# 96    696                                      Inferno    Sony     $220.0
# 97    697                                Green Lantern      WB     $219.9
# 98    698                                 The Terminal      DW     $219.4
# 99    699                        What Happens in Vegas     Fox     $219.4
# 100   700                             It's Complicated    Uni.     $219.1
#
#                 4             5             6             7      8
# ...

# %%
url8 = "https://www.boxofficemojo.com/alltime/world/?pagenum=8&p=.htm"
tables8 = pd.read_html(url8)[1]
tables8
# Out:
#        0                         1       2          3             4  \
# 0   Rank                     Title  Studio  Worldwide  Domestic / %
# 1    701                Knocked Up    Uni.     $219.1        $148.8
# 2    702          Captain Phillips    Sony     $218.8        $107.1
# 3    703       The Prince of Egypt      DW     $218.6        $101.4
# 4    704              Jack Reacher    Par.     $218.3         $80.1
# ..   ...                       ...     ...        ...           ...
# 86   786                 Yogi Bear      WB     $201.6        $100.2
# 87   787       Garfield: The Movie     Fox     $200.8         $75.4
# 88   788               Cats & Dogs      WB     $200.7         $93.4
# 89   789  The Hunt for Red October    Par.     $200.5        $122.0
# 90   790                  Valkyrie      UA     $200.3         $83.1
#
#                5             6             7      8
# 0   Domestic / %  Overseas / %  Overseas / %  Year^
# ...

# %%
data_withOverseasData = pd.concat([tables, tables2, tables3, tables4, tables5, tables6, tables7, tables8], axis=0)

# %%
data_withOverseasData.to_csv("")
# Out:
#        0                             1       2          3             4  \
# 0   Rank                         Title  Studio  Worldwide  Domestic / %
# 1      1             Avengers: Endgame      BV   $2,797.8        $858.4
# 2      2                        Avatar     Fox   $2,789.7        $760.5
# 3      3                       Titanic    Par.   $2,187.5        $659.4
# 4      4  Star Wars: The Force Awakens      BV   $2,068.2        $936.7
# ..   ...                           ...     ...        ...           ...
# 86   786                     Yogi Bear      WB     $201.6        $100.2
# 87   787           Garfield: The Movie     Fox     $200.8         $75.4
# 88   788                   Cats & Dogs      WB     $200.7         $93.4
# 89   789      The Hunt for Red October    Par.     $200.5        $122.0
# 90   790                      Valkyrie      UA     $200.3         $83.1
#
#                5             6             7      8
# ...

# %%
nms = nms.dropna(thresh=2)

# %%
df[df['name'].notnull()]
