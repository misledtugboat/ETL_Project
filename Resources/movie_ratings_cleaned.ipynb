# %%
import pandas as pd

# %%
data = pd.read_csv ("movie_ratings.csv")
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#   Awards    Country  DVD             Director   Language  \
# 0    NaN        USA  NaN        Rose Cummings    English
# 1    NaN        USA  NaN          James Byrne        NaN
# 2    NaN        USA  NaN  Dimitri Buchowetzki        NaN
# 3    NaN        USA  NaN        Julia Hechler    English
# 4    NaN  Sri Lanka  NaN      Udara Siriruwan  Sinhalese
#
#                                                 Plot Poster Production Rated  \
# 0  Rachel constantly hears her baby cry from the ...    NaN        NaN   NaN
# 1  The struggle against unfortunate circumstances...    NaN        NaN   NaN
# 2                                                NaN    NaN        NaN   NaN
# 3  A Gift introduces Samuel Green, Washington Sta...    NaN        NaN   NaN
# 4                                                NaN    NaN        NaN   NaN
#
#     Released Runtime              Title   Type Website  Year     imdbID  \
# 0  26-Apr-12  20 min      Baby's Breath  movie     NaN  2012  tt2268369
# ...

# %%
data_cleanded = data.drop(['DVD', 'Poster', 'Production', 'Runtime', 'Website', 'imdbID', "Plot", "Type"], axis=1)

# %%
data_cleanded = data_cleanded[data_cleanded["imdbRating"].notnull()]

# %%
data_cleanded
# Out:
#                                                    Awards  \
# 9                                                     NaN
# 15                                                 1 win.
# 16                                                    NaN
# 18                                                    NaN
# 21                                          1 nomination.
# ...                                                   ...
# 178682  Nominated for 1 Oscar. Another 7 wins & 13 nom...
# 178683                            3 wins & 9 nominations.
# 178684  Won 1 Golden Globe. Another 4 wins & 23 nomina...
# 178685                           7 wins & 14 nominations.
# 178686  Nominated for 5 Oscars. Another 10 wins & 75 n...
#
#                         Country                     Director  \
# 9                           USA                          NaN
# 15                          USA                    Matt Hish
# 16                          NaN                  Meiert Avis
# ...

# %%
data_cleanded.to_csv ("movie_ratings_cleaned.csv")
